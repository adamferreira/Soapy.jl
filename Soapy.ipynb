# %%
using Soapy
# Make a soap with most commun oils
recipe = Soapy.RecipeCalculator("oils_basic.json")
# Make a 1kg soap
recipe.target_weight = 1000.0
# Use recommended qualities for a balanced soap
recipe.target_qualities = Soapy.recommended_qualities()
# Maximise the INS (overall) score of the soap
Soapy.maximise_quality(recipe, "INS")
# Out:
# Mixing up to 41 oils together out of 41
# Will keep soap mass at 1000.0g
# Soap composition :
# 	Oils (3) :
# 		Almond Butter = 248.19g
# 		Cocoa butter = 223.11g
# 		Coconut oil 76 degree = 179.61g
# 		Total = 650.91g
# 	Water = 226.14g
# 	Lye = 96.92g
# 	Fragrance = 26.04g
# 	Total = 1000.0g
# Soap quality (Recommended) :
# 	Hardness = 52 (29, 54)
# 	Cleansing = 18 (12, 22)
# 	Bubbly = 18 (14, 46)
# 	Creamy = 33 (16, 48)
# 	Conditioning = 43 (44, 69)*
# 	Iodine = 42 (41, 70)
# 	INS = 170 (136, 170)
